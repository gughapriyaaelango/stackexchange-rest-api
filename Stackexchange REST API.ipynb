# %%
import requests
import json

# %%
response = requests.get('https://api.stackexchange.com/2.3/answers?order=desc&sort=activity&site=stackoverflow')
print(response)
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# {'items': [{'owner': {'account_id': 2111, 'reputation': 1610, 'user_id': 2910, 'user_type': 'registered', 'accept_rate': 67, 'profile_image': 'https://www.gravatar.com/avatar/f3bfbe6f862c6a104cc9196c1270fe10?s=256&d=identicon&r=PG', 'display_name': 'benc', 'link': 'https://stackoverflow.com/users/2910/benc'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185883, 'creation_date': 1705185883, 'answer_id': 77813361, 'question_id': 77725075, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 30238450, 'reputation': 1, 'user_id': 23174123, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/wkc19.png?s=256&g=1', 'display_name': 'darkplasma', 'link': 'https://stackoverflow.com/users/23174123/darkplasma'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185877, 'creation_date': 1705185877, 'answer_id': 77813359, 'question_id': 77812872, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 9625303, 'reputation': 403, 'user_id': 7145112, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/PBnt3.jpg?s=256&g=1', 'display_name': 'Hadi R.', 'link': 'https://stackoverflow.com/users/7145112/hadi-r'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185860, 'creation_date': 1705185860, 'answer_id': 77813357, 'question_id': 37582730, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 6722366, 'reputation': 1098, 'user_id': 5181837, 'user_type': 'registered', 'accept_rate': 60, 'profile_image': 'https://www.gravatar.com/avatar/2198f092ca41d0210593592a41dc4694?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'Ben A.', 'link': 'https://stackoverflow.com/users/5181837/ben-a'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185860, 'creation_date': 1705185860, 'answer_id': 77813356, 'question_id': 77813329, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 30327221, 'reputation': 1, 'user_id': 23241422, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a/ACg8ocL64zOzhNcuSAWkz9tEnsOfy95GFay6tlLVRQavbzjaen0=k-s256', 'display_name': 'Roc', 'link': 'https://stackoverflow.com/users/23241422/roc'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185848, 'last_edit_date': 1705185848, 'creation_date': 1705185825, 'answer_id': 77813354, 'question_id': 41656180, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 2644455, 'reputation': 645, 'user_id': 2287467, 'user_type': 'registered', 'accept_rate': 75, 'profile_image': 'https://www.gravatar.com/avatar/db42379d3f6d98ac2458ab0f2c32581c?s=256&d=identicon&r=PG', 'display_name': 'JavaHead', 'link': 'https://stackoverflow.com/users/2287467/javahead'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185839, 'creation_date': 1705185839, 'answer_id': 77813355, 'question_id': 77803138, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 24775339, 'reputation': 1, 'user_id': 18658943, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/aa69f2439f4de3a97bc8502bf4aad6b2?s=256&d=identicon&r=PG', 'display_name': 'Envy', 'link': 'https://stackoverflow.com/users/18658943/envy'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185805, 'last_edit_date': 1705185805, 'creation_date': 1705185526, 'answer_id': 77813339, 'question_id': 77811935, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 23126139, 'reputation': 49, 'user_id': 17231916, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Ghb3S5GmnpiFJQ9wxDBtmYGzljbmPoSIVExVKss=k-s256', 'display_name': 'Marshall', 'link': 'https://stackoverflow.com/users/17231916/marshall'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185783, 'creation_date': 1705185783, 'answer_id': 77813352, 'question_id': 9825071, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 2261104, 'reputation': 933, 'user_id': 1991185, 'user_type': 'registered', 'accept_rate': 68, 'profile_image': 'htt ...

# %%
print(response.json()['items'])
# Out:
# [{'owner': {'account_id': 2111, 'reputation': 1610, 'user_id': 2910, 'user_type': 'registered', 'accept_rate': 67, 'profile_image': 'https://www.gravatar.com/avatar/f3bfbe6f862c6a104cc9196c1270fe10?s=256&d=identicon&r=PG', 'display_name': 'benc', 'link': 'https://stackoverflow.com/users/2910/benc'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185883, 'creation_date': 1705185883, 'answer_id': 77813361, 'question_id': 77725075, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 30238450, 'reputation': 1, 'user_id': 23174123, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/wkc19.png?s=256&g=1', 'display_name': 'darkplasma', 'link': 'https://stackoverflow.com/users/23174123/darkplasma'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185877, 'creation_date': 1705185877, 'answer_id': 77813359, 'question_id': 77812872, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 9625303, 'reputation': 403, 'user_id': 7145112, 'user_type': 'registered', 'profile_image': 'https://i.stack.imgur.com/PBnt3.jpg?s=256&g=1', 'display_name': 'Hadi R.', 'link': 'https://stackoverflow.com/users/7145112/hadi-r'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185860, 'creation_date': 1705185860, 'answer_id': 77813357, 'question_id': 37582730, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 6722366, 'reputation': 1098, 'user_id': 5181837, 'user_type': 'registered', 'accept_rate': 60, 'profile_image': 'https://www.gravatar.com/avatar/2198f092ca41d0210593592a41dc4694?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'Ben A.', 'link': 'https://stackoverflow.com/users/5181837/ben-a'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185860, 'creation_date': 1705185860, 'answer_id': 77813356, 'question_id': 77813329, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 30327221, 'reputation': 1, 'user_id': 23241422, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a/ACg8ocL64zOzhNcuSAWkz9tEnsOfy95GFay6tlLVRQavbzjaen0=k-s256', 'display_name': 'Roc', 'link': 'https://stackoverflow.com/users/23241422/roc'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185848, 'last_edit_date': 1705185848, 'creation_date': 1705185825, 'answer_id': 77813354, 'question_id': 41656180, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 2644455, 'reputation': 645, 'user_id': 2287467, 'user_type': 'registered', 'accept_rate': 75, 'profile_image': 'https://www.gravatar.com/avatar/db42379d3f6d98ac2458ab0f2c32581c?s=256&d=identicon&r=PG', 'display_name': 'JavaHead', 'link': 'https://stackoverflow.com/users/2287467/javahead'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185839, 'creation_date': 1705185839, 'answer_id': 77813355, 'question_id': 77803138, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 24775339, 'reputation': 1, 'user_id': 18658943, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/aa69f2439f4de3a97bc8502bf4aad6b2?s=256&d=identicon&r=PG', 'display_name': 'Envy', 'link': 'https://stackoverflow.com/users/18658943/envy'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185805, 'last_edit_date': 1705185805, 'creation_date': 1705185526, 'answer_id': 77813339, 'question_id': 77811935, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 23126139, 'reputation': 49, 'user_id': 17231916, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Ghb3S5GmnpiFJQ9wxDBtmYGzljbmPoSIVExVKss=k-s256', 'display_name': 'Marshall', 'link': 'https://stackoverflow.com/users/17231916/marshall'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1705185783, 'creation_date': 1705185783, 'answer_id': 77813352, 'question_id': 9825071, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'account_id': 2261104, 'reputation': 933, 'user_id': 1991185, 'user_type': 'registered', 'accept_rate': 68, 'profile_image': 'https://www.g ...

# %%
for data in response.json()['items']:
    print(data['answer_id'])
    print(data['question_id'])
# Out:
# 77813361
# 77725075
# 77813359
# 77812872
# 77813357
# 37582730
# 77813356
# 77813329
# 77813354
# 41656180
# 77813355
# 77803138
# 77813339
# 77811935
# 77813352
# 9825071
# 77813351
# 77807572
# 77813109
# 77812767
# 77813349
# 24011399
# 77813348
# 33506799
# 77813347
# 77813346
# 77813341
# 77813194
# 77813340
# 77813213
# 77813232
# 5424138
# 77813337
# 77811765
# 77813336
# 77812252
# 77813335
# 69635689
# 77813333
# 63144349
# 72620440
# 72620279
# 59809313
# 59808974
# 77813322
# 77813105
# 77813156
# 77810046
# 77810222
# 77809478
# 77813330
# 77454538
# 77813298
# 77813145
# 77813305
# 77810805
# 77813327
# 71913765
# 77813326
# 75151786

# %%
response = requests.get('https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow')
print(response.json()['items'])
# Out:
# [{'tags': ['c++', 'constexpr-function'], 'owner': {'account_id': 22231659, 'reputation': 219, 'user_id': 16467709, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/0d65f6c6c45806cf0344627b66ee91d0?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'ntos', 'link': 'https://stackoverflow.com/users/16467709/ntos'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1705186194, 'creation_date': 1705186194, 'question_id': 77813367, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/77813367/the-size-paramter-of-stdarray-does-not-accept-a-constexpr-function', 'title': 'the size paramter of std::array does not accept a constexpr function'}, {'tags': ['java', 'excel', 'xml'], 'owner': {'account_id': 30326726, 'reputation': 1, 'user_id': 23241066, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a/ACg8ocIhjRPkKW4Lg_bGYKleC5s6M1FhMPx-HWHidS2ax65uvQ=k-s256', 'display_name': 'Help777', 'link': 'https://stackoverflow.com/users/23241066/help777'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1705186187, 'creation_date': 1705186187, 'question_id': 77813366, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/77813366/a-excel-type-xml', 'title': 'A Excel Type xml'}, {'tags': ['sql', 'postgresql', 'data-modeling'], 'owner': {'account_id': 100757, 'reputation': 4223, 'user_id': 271450, 'user_type': 'registered', 'accept_rate': 50, 'profile_image': 'https://i.stack.imgur.com/drbGB.jpg?s=256&g=1', 'display_name': 'Jonathan', 'link': 'https://stackoverflow.com/users/271450/jonathan'}, 'is_answered': False, 'view_count': 112, 'answer_count': 0, 'score': 0, 'last_activity_date': 1705186163, 'creation_date': 1680463286, 'last_edit_date': 1705186163, 'question_id': 75914146, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/75914146/rbac-for-postgres-sql-data-model-for-owner', 'title': 'RBAC for Postgres SQL Data Model for Owner'}, {'tags': ['python-3.x', 'windows'], 'owner': {'account_id': 18295397, 'reputation': 11, 'user_id': 13321445, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/14492e412461ffd075f21f66f55fbdf8?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'Koroski', 'link': 'https://stackoverflow.com/users/13321445/koroski'}, 'is_answered': False, 'view_count': 1133, 'answer_count': 2, 'score': 0, 'last_activity_date': 1705186123, 'creation_date': 1587535712, 'last_edit_date': 1705185998, 'question_id': 61358356, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/61358356/how-do-i-write-more-than-one-line-of-code-in-python-idle', 'title': 'How do I write more than one line of code in Python IDLE?'}, {'tags': ['sql-server', 'powershell', 'csv', 'encoding'], 'owner': {'account_id': 1246684, 'reputation': 217, 'user_id': 1207971, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/8c7a43176b9d10c1bcdb52cd15ba10ba?s=256&d=identicon&r=PG', 'display_name': 'Eseosa Omoregie', 'link': 'https://stackoverflow.com/users/1207971/eseosa-omoregie'}, 'is_answered': False, 'view_count': 21, 'answer_count': 0, 'score': 0, 'last_activity_date': 1705186123, 'creation_date': 1705182818, 'last_edit_date': 1705186123, 'question_id': 77813227, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/77813227/powershell-generating-csv-file-with-asci-encoding-due-to-hashed-field-instead-of', 'title': 'PowerShell generating CSV file with ASCI encoding due to hashed field instead of UTF-8'}, {'tags': ['mongodb', 'mongodb-atlas'], 'owner': {'account_id': 102645, 'reputation': 6570, 'user_id': 275414, 'user_type': 'registered', 'accept_rate': 72, 'profile_image': 'https://www.gravatar.com/avatar/81f61aa71395ac089a0b29ecf88283d5?s=256&d=identicon&r=PG', 'display_name': 'RussellHarrower', 'link': 'https://stackoverflow.com ...

# %%
for data in response.json()['items']:
    if data['answer_count']== 0:
        print(data['title'])
        print(data['link'])
# Out:
# the size paramter of std::array does not accept a constexpr function
# https://stackoverflow.com/questions/77813367/the-size-paramter-of-stdarray-does-not-accept-a-constexpr-function
# A Excel Type xml
# https://stackoverflow.com/questions/77813366/a-excel-type-xml
# RBAC for Postgres SQL Data Model for Owner
# https://stackoverflow.com/questions/75914146/rbac-for-postgres-sql-data-model-for-owner
# PowerShell generating CSV file with ASCI encoding due to hashed field instead of UTF-8
# https://stackoverflow.com/questions/77813227/powershell-generating-csv-file-with-asci-encoding-due-to-hashed-field-instead-of
# How can i display the number of rows, in JS, using a div with contenteditable=&quot;true&quot;? (using textarea worked, but with div not)?
# https://stackoverflow.com/questions/77813342/how-can-i-display-the-number-of-rows-in-js-using-a-div-with-contenteditable-t
# The Login in asp.net core(model-view-controller)
# https://stackoverflow.com/questions/77813362/the-login-in-asp-net-coremodel-view-controller
# Applying Natural ShapeStyle for system and asset image in SwiftUI
# https://stackoverflow.com/questions/77813360/applying-natural-shapestyle-for-system-and-asset-image-in-swiftui
# Should the navigation property be in the constructor? Entityframeworkcore
# https://stackoverflow.com/questions/77813358/should-the-navigation-property-be-in-the-constructor-entityframeworkcore
# In version 13 of Next js, the Image cannot be extracted, and it gives an error
# https://stackoverflow.com/questions/77813334/in-version-13-of-next-js-the-image-cannot-be-extracted-and-it-gives-an-error
# Reading UDP packets containing JPG video frames with python
# https://stackoverflow.com/questions/77813343/reading-udp-packets-containing-jpg-video-frames-with-python
# How to use numbers with useParams?
# https://stackoverflow.com/questions/77813353/how-to-use-numbers-with-useparams
# What allocation other than one on heap and stack?
# https://stackoverflow.com/questions/77813274/what-allocation-other-than-one-on-heap-and-stack
